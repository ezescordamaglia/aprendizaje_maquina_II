# %%
import pandas as pd
import pickle as pkl

# %%
with open(r'C:\Users\santi\IA\3 Bimestre\Eze\aprendizaje_maquina_II\TP_Integrador\model.pkl', 'rb') as model_file:
    model_nuevo = pkl.load(model_file)
with open(r'C:\Users\santi\IA\3 Bimestre\Eze\aprendizaje_maquina_II\TP_Integrador\src\.modelo_orig.pkl', 'rb') as model_file:
    modelo_original = pkl.load(model_file)
df=pd.read_csv(r"C:\Users\santi\IA\3 Bimestre\Eze\aprendizaje_maquina_II\TP_Integrador\data\Transformed\Test_BigMart_Prepared.csv",sep=";")

# %%
df_predicciones_originales=df
df_predicciones_nuevas=df

# %%
predicciones_originales = modelo_original.predict(df_predicciones_originales)
predicciones_nuevas = model_nuevo.predict(df_predicciones_nuevas)

# %%
df_predicciones_originales["predicciones"]=predicciones_originales
df_predicciones_nuevas["predicciones"]=predicciones_nuevas

# %%
df_predicciones_originales.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0       20.750         0.007565         2                         21
# 1        8.300         0.038428         1                         13
# 2       14.600         0.099575         4                         22
# 3        7.315         0.015388         3                         13
# 4       13.600         0.118599         4                         35
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type_Grocery Store  \
# 0            1                     2                          0
# 1            0                     1                          0
# 2            0                     0                          1
# 3            0                     1                          0
# 4            1                     0                          0
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                              1                              0
# ...

# %%
df_predicciones_nuevas.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0       20.750         0.007565         2                         21
# 1        8.300         0.038428         1                         13
# 2       14.600         0.099575         4                         22
# 3        7.315         0.015388         3                         13
# 4       13.600         0.118599         4                         35
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type_Grocery Store  \
# 0            1                     2                          0
# 1            0                     1                          0
# 2            0                     0                          1
# 3            0                     1                          0
# 4            1                     0                          0
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                              1                              0
# ...

# %%
df_original = df
df_original["predictions"] = predictions
